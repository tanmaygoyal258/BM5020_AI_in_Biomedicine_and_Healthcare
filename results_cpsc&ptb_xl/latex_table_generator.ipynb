# %%
Precisions_combined = [0.805,0.88,0.6,0.777,0.92,0.833,0.709,0.79,0.723]

Recalls_combined = [0.925,0.78,0.579,0.85,0.837,0.722,0.908,0.482,0.773]

F1s_combined = [0.861,0.827,0.59,0.812,0.876,0.773,0.796,0.598,0.747]

AUCs_combined = [0.929,0.983,0.892,0.984,0.992,0.968,0.989,0.941,0.941]

Accs_combined = [0.839,0.985,0.934,0.966,0.97,0.986,0.971,0.963,0.894]

Average_score_combined = [0.782,0.762,0.765,0.958,0.945]

# %%
Precisions_original = [0.786,0.938,0.894,0.935,0.913,0.771,0.922,0.782,0.474]

Recalls_original = [0.906,0.931,0.894,1.,0.966,0.857,0.787,0.756,0.5,]

F1s_original = [0.842,0.934,0.894,0.967,0.939,0.812,0.849,0.768,0.486]

AUCs_original = [0.972,0.989,0.988,1.,0.993,0.972,0.973,0.938,0.911]

Accs_original = [0.958,0.975,0.974,0.997,0.968,0.964,0.969,0.94,0.972]

Average_scores_original = [0.824,0.844,0.832,0.971,0.969]

# %%
Precisions_model1 = [0.756,0.5,0.636,0.734,0.864,0.862,0.735,0.31,0.638]

Recalls_model1 = [0.894,0.508,0.502,0.817,0.874,0.258,0.925,0.427,0.689]

F1s_model1 = [0.819,0.504,0.561,0.773,0.869,0.397,0.819,0.359,0.663]

AUCs_model1 = [0.881,0.927,0.916,0.978,0.989,0.826,0.985,0.855,0.903]

Accs_model1 = [0.787,0.954,0.936,0.958,0.967,0.973,0.975,0.912,0.859]

Average_scores_model1 = [0.67,0.655,0.64,0.918,0.924]

# %%
classes = ['SNR' , 'AF' , 'IAVB' , 'LBBB' , 'RBBB' , 'PAC' , 'PVC' , 'STD' , 'STE']

# %%
for i in range(9):
    print(f'\\textbf{{{classes[i]}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{Precisions_original[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{Precisions_model1[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{Precisions_combined[i]:.3f}}}')
    
    print(f'&\\multicolumn{{1}}{{c|}}{{{Recalls_original[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{Recalls_model1[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{Recalls_combined[i]:.3f}}}')
    
    print(f'&\\multicolumn{{1}}{{c|}}{{{F1s_original[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{F1s_model1[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{F1s_combined[i]:.3f}}}')

    print(f'&\\multicolumn{{1}}{{c|}}{{{AUCs_original[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{AUCs_model1[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{AUCs_combined[i]:.3f}}}')

    print(f'&\\multicolumn{{1}}{{c|}}{{{Accs_original[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{Accs_model1[i]:.3f}}}')
    print(f'&\\multicolumn{{1}}{{c|}}{{{Accs_combined[i]:.3f}}}')

    print("\\\\\\hline")
# Out:
# \textbf{SNR}
# &\multicolumn{1}{c|}{0.786}
# &\multicolumn{1}{c|}{0.756}
# &\multicolumn{1}{c|}{0.805}
# &\multicolumn{1}{c|}{0.906}
# &\multicolumn{1}{c|}{0.894}
# &\multicolumn{1}{c|}{0.925}
# &\multicolumn{1}{c|}{0.842}
# &\multicolumn{1}{c|}{0.819}
# &\multicolumn{1}{c|}{0.861}
# &\multicolumn{1}{c|}{0.972}
# &\multicolumn{1}{c|}{0.881}
# &\multicolumn{1}{c|}{0.929}
# &\multicolumn{1}{c|}{0.958}
# &\multicolumn{1}{c|}{0.787}
# &\multicolumn{1}{c|}{0.839}
# \\\hline
# \textbf{AF}
# &\multicolumn{1}{c|}{0.938}
# &\multicolumn{1}{c|}{0.500}
# &\multicolumn{1}{c|}{0.880}
# &\multicolumn{1}{c|}{0.931}
# &\multicolumn{1}{c|}{0.508}
# &\multicolumn{1}{c|}{0.780}
# &\multicolumn{1}{c|}{0.934}
# &\multicolumn{1}{c|}{0.504}
# &\multicolumn{1}{c|}{0.827}
# &\multicolumn{1}{c|}{0.989}
# &\multicolumn{1}{c|}{0.927}
# &\multicolumn{1}{c|}{0.983}
# &\multicolumn{1}{c|}{0.975}
# &\multicolumn{1}{c|}{0.954}
# &\multicolumn{1}{c|}{0.985}
# \\\hline
# \textbf{IAVB}
# &\multicolumn{1}{c|}{0.894}
# ...
